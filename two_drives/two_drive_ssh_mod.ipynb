# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import scipy.linalg as la
import scipy.integrate as integrate
import kwant
from scipy.linalg import ishermitian

# %% [markdown]
# This code attempts to replicate the results of PhysRevB.107.094310 (Olin and Lee), and then extend on their idea by applying the incommensurate limit.

# %% [markdown]
# This block sets up the initial hamiltonian for a finite chain.

# %%
sigmax = np.matrix([[0., 1.],[1., 0.]])
sigmay = np.matrix([[0., -1j*1.],[1j*1., 0.]])
sigmaz = np.matrix([[1., 0.],[0., -1.]])

U1 = lambda u, w1, w2, a1, a2, t: u*(1 + 2*a1*np.cos(w1*t) + 2*a2*np.cos(w2*t))
U2 = lambda v, w1, w2, a1, a2, t: v*(1 - 2*a1*np.cos(w1*t) - 2*a2*np.cos(w2*t))
Va = lambda v, w1, w2, a, a1, a2, theta, t: a*(a1*np.cos(w1*t + theta) + a2*np.cos(w2*t + theta))
Vb = lambda v, w1, w2, a, a1, a2, theta, t: a*(a1*np.cos(w1*t - theta) + a2*np.cos(w2*t - theta))

def bulk2driveSSH_ham(u, v, w1, w2, theta, a, a1, a2, k, t):
    return np.array([[2*Va(v, w1, w2, a, a1, a2, theta, t)*np.cos(k), U1(u, w1, w2, a1, a2, t) + U2(u, w1, w2, a1, a2, t)*np.exp(-1j*k)],[U1(u, w1, w2, a1, a2, t) + U2(u, w1, w2, a1, a2, t)*np.exp(1j*k), 2*Vb(v, w1, w2, a, a1, a2, theta, t)*np.cos(k)]])

def twodriveSSH_ham(u, v, w1, w2, theta, a, a1, a2, t, L):
    u1 = U1(u, w1, w2, a1, a2, t)
    u2 = U2(u, w1, w2, a1, a2, t)
    va = Va(v, w1, w2, a, a1, a2, theta, t)
    vb = Vb(v, w1, w2, a, a1, a2, theta, t)
    
    lat = kwant.lattice.chain()
    sys = kwant.Builder()
    A = lambda i: lat(2 * i)
    B = lambda i: lat(2 * i + 1)
    
    for i in range(L):  #onsite
        sys[A(i)] = 0.0
        sys[B(i)] = 0.0
    
    for i in range(L):  # Intracell A to B
        sys[A(i), B(i)] = u1 
    
    for i in range(L - 1):  
        sys[A(i), B(i + 1)] = u2  # Intercell Ai to Bi
        sys[A(i), A(i + 1)] = va  # Intercell Ai to Ai+1 
        sys[B(i), B(i + 1)] = vb  # Intercell Bi to Bi+1  
    f_sys = sys.finalized()
    ham = f_sys.hamiltonian_submatrix(sparse=False)
    return ham

# %% [markdown]
# We need to calculate the Flouqet hamiltonian for m floquet modes which will give us 2mn x 2mn Floquet hamiltonian for n unit cells.

# %%
def bulk2driveSSH_nm_ham(n, m, u, v, w1, w2, w, theta, a, a1, a2, k):
    hnm = np.zeros((2,2), dtype=complex)
    T = 2*np.pi/w     #2*Va(v, w1, w2, alpha, theta, t)*np.cos(k)
    hnm[0,0] = (1/T)*(integrate.quad(lambda t:np.real(( 2*Va(v, w1, w2, a, a1, a2, theta, t)*np.cos(k) )*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0] + 1j*integrate.quad(lambda t:np.imag(( 2*Va(v, w1, w2, a, a1, a2, theta, t)*np.cos(k) )*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0])
    hnm[1,1] = (1/T)*(integrate.quad(lambda t:np.real(( 2*Vb(v, w1, w2, a, a1, a2, theta, t)*np.cos(k) )*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0] + 1j*integrate.quad(lambda t:np.imag(( 2*Vb(v, w1, w2, a, a1, a2, theta, t)*np.cos(k) )*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0])
    hnm[0,1] = (1/T)*(integrate.quad(lambda t:np.real(( U1(u, w1, w2, a1, a2, t) + U2(u, w1, w2, a1, a2, t)*np.exp(-1j*k) )*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0] + 1j*integrate.quad(lambda t:np.imag(( U1(u, w1, w2, a1, a2, t) + U2(u, w1, w2, a1, a2, t)*np.exp(-1j*k)  )*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0])
    hnm[1,0] = (1/T)*(integrate.quad(lambda t:np.real(( U1(u, w1, w2, a1, a2, t) + U2(u, w1, w2, a1, a2, t)*np.exp(1j*k) )*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0] + 1j*integrate.quad(lambda t: np.imag(( U1(u, w1, w2, a1, a2, t) + U2(u, w1, w2, a1, a2, t)*np.exp(1j*k) )*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0])
    return hnm

def Hf_bulk(lat, u, v, w1, w2, w, theta, a, a1, a2, k):
    blocks = []
    for i in range(1, lat+1):
        row = []
        for j in range(1, lat+1):
            matij = bulk2driveSSH_nm_ham(i, j, u, v, w1, w2, w, theta, a, a1, a2, k)
            if (i==j):
                matij = matij - i*w*np.eye(2,dtype=complex)
            row.append(matij)
        blocks.append(row)
    m = np.block(blocks)
    # for i in range(m.shape[0]):
    #     m[i,i] = m[i,i] - i*W
    return m

def twodriveSSH_nm_ham(n, m, u, v, w1, w2, w, theta, a, a1, a2, L):
    t = 2*np.pi/w
    lat = kwant.lattice.chain(norbs=1)
    sys = kwant.Builder()
    A = lambda i: lat(2 * i)
    B = lambda i: lat(2 * i + 1)
    
    for i in range(L):  #onsite
        sys[A(i)] = 0.0
        sys[B(i)] = 0.0

    u1 = (1/t)*(integrate.quad(lambda t: np.real(( U1(u, w1, w2, a1, a2, t) )*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0] + 1j*integrate.quad(lambda t: np.imag(( U1(u, w1, w2, a1, a2, t) )*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0])
    for i in range(L):  # Intracell A to B
        sys[A(i), B(i)] = u1

    u2 = (1/t)*(integrate.quad(lambda t: np.real(( U2(u, w1, w2, a1, a2, t) )*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0] + 1j*integrate.quad(lambda t: np.imag(( U2(u, w1, w2, a1, a2, t) )*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0])
    va = (1/t)*(integrate.quad(lambda t: np.real(( Va(v, w1, w2, a, a1, a2, theta, t) )*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0] + 1j*integrate.quad(lambda t: np.imag( Va(v, w1, w2, a, a1, a2, theta, t)*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0])
    vb = (1/t)*(integrate.quad(lambda t: np.real(( Va(v, w1, w2, a, a1, a2, theta, t) )*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0] + 1j*integrate.quad(lambda t: np.imag( Va(v, w1, w2, a, a1, a2, theta, t)*np.exp(1j*(m-n)*w*t)), 0, 2*np.pi/w)[0])
    for i in range(L - 1):  
        sys[A(i), B(i + 1)] = u2  # Intercell Ai to Bi
        sys[A(i), A(i + 1)] = va  # Intercell Ai to Ai+1 
        sys[B(i), B(i + 1)] = vb  # Intercell Bi to Bi+1  
    f_sys = sys.finalized()
    ham = f_sys.hamiltonian_submatrix(sparse=False)
    return ham
    

def Hf_finite(lat, u, v, w1, w2, w, theta, a, a1, a2, L):
    blocks = []
    for i in range(1, lat+1):
        row = []
        for j in range(1, lat+1):
            matij = twodriveSSH_nm_ham(i, j, u, v, w1, w2, w, theta, a, a1, a2, L)
            if (i==j):
                matij = matij - i*w*np.eye(2*L,dtype=complex)
            row.append(matij)
        blocks.append(row)
    m = np.block(blocks)
    # for i in range(m.shape[0]):
    #     m[i,i] = m[i,i] - i*W
    return m

# %%
p = 1
q = 2
w2 = 8
w1 = (p/q)*w2
w = w2/q
alpha = 0
g0 = 2
delta = 0#0.5
u = g0 - delta
v = g0 + delta
theta = 1
dk = 0.05
a = 1
a1 = 1
a2 = 1

kv = np.arange(-np.pi, np.pi+dk , dk)
latsize = 3
bands = [ [] for i in range(2*latsize) ]
for i in kv:
    eigs = np.sort(la.eigvals(Hf_bulk(latsize, u, v, w1, w2, w, theta, a, a1, a2, i)))
    for j in range(2*latsize):
        bands[j].append(np.real(eigs[j]))

# %%
fig, ax = plt.subplots(1,1)
for i in range(2*latsize):
    ax.plot(kv, bands[i], 'green')
    # ax.fill_between(kv, bands[i], facecolor ='orange', alpha=0.1)
    # ax.fill_between(kv, 1, where=bands[i] == 0, facecolor1='green', alpha=.5)
a = 0.3
c = 'steelblue'
o = 'orange'
r = 'r'
# b = 'b'
# ax.axhspan(gaps[0,0],gaps[0,1], 0, 1,facecolor =c, alpha = a)
# ax.axhspan(gaps[0,2],gaps[0,3], 0, 1,facecolor =o, alpha = a)
# ax.axhspan(gaps[0,4],gaps[0,5], 0, 1,facecolor =c, alpha = a)
# ax.axhspan(gaps[0,6],gaps[0,7], 0, 1,facecolor =r, alpha = a)
# ax.axhspan(gaps[0,8],gaps[0,9], 0, 1,facecolor =b, alpha = a)
plt.hlines(y=[-1*w, -2*w, -3*w, -w/2, -3*w/2, -5*w/2], xmin = -np.pi, xmax = np.pi, colors=['b','b','b','r','r','r' ], linestyles=['--','--','--','--','--','--'], alpha=0.6)
tit = 'u = '+str(u)+ ' v = ' + str(v) + '  W (g0) = ' + str(w/g0)
plt.title(tit)
# plt.savefig('quasiBandstucture/'+tit+'.png')
plt.show()

# %%
p = 1
q = 2
w2 = 1
w1 = (p/q)*w2
w = w2/q
alpha = 1
g0 = 2
delta = -0.3
u = g0 - delta
v = g0 + delta
theta = 1
L = 10
a = 0
a1 = 1
a2 = 1
modes = 3

ham = Hf_finite(modes, u, v, w1, w2, w, theta, a, a1, a2, L)
eigs, eigv = la.eig(ham)
eigs = np.real(eigs)

# %%
inds = []
for i in range(len(eigs)):
    for j in range(len(eigs)):
        if (abs(np.real(eigs[i])-np.real(eigs[j]))<1e-7 and i != j):
            inds.append([i,j])
# print(len(inds))
# print(inds)

# %%
len(inds)
# Out:
# 32

# %%
# for i in range(len(eigv)):
#     v1 = eigv[i]
#     denv1 = np.conjugate(v1)*v1
#     plt.bar([i for i in range(len(denv1))],np.real(denv1))
#     plt.savefig('density/'+str(i)+'.png')
#     plt.clf()
#     plt.close()

# %%
import multiprocessing as mp
import os

def plot_density(i):
    v1 = eigv[i]
    denv1 = np.conjugate(v1) * v1
    plt.bar(range(len(denv1)), np.real(denv1))
    plt.title('u = '+str(u) + '  v = '+str(v))
    plt.savefig("denTopo/"+str(i)+".png")
    plt.clf()
    plt.close()

if __name__ == "__main__":
    with mp.Pool(processes=mp.cpu_count()) as pool:
        pool.map(plot_density, range(len(eigv)))

# %%
# eigs = np.sort(la.eigvals(ham))
# eig, eigv = la.eig(ham)
eigs = np.sort(eigs)
plt.figure(figsize=(10,10))
plt.plot(np.real(eigs), 'r-')
plt.plot(np.real(eigs), 'bo')
plt.title('u = '+str(u) + '  v = '+str(v))
plt.hlines(y=[w, 2*w, 3*w], xmin=0, xmax=len(eigs), color = 'green', linestyle='--')#, alpha=0.4)
plt.show()
# plt.savefig('trivial.png')

# %%
def calculate_bott(H, Lx, Ly, ndof=2):
    L = Lx * Ly
    dim = ndof * L

    # --- Site coordinates (1D arrays) ---
    cell_x = np.zeros(dim, dtype=int)
    cell_y = np.zeros(dim, dtype=int)

    for x in range(Lx):
        for y in range(Ly):
            i = x * Ly + y
            for sub in range(ndof):
                idx = ndof * i + sub
                cell_x[idx] = x
                cell_y[idx] = y

    # --- Diagonalize Hamiltonian ---
    evals, evecs = la.eigh(H)

    # --- Projector onto occupied states ---
    occupied = evals < 0
    P = evecs[:, occupied] @ evecs[:, occupied].conj().T

    # --- Unitary position operators ---
    theta = (2.0 * np.pi / Lx) * cell_x
    phi_b = (2.0 * np.pi / Ly) * cell_y
    Ux = np.diag(np.exp(1j * theta))
    Uy = np.diag(np.exp(1j * phi_b))

    # --- Projected unitaries ---
    U = P @ Ux @ P
    V = P @ Uy @ P

    # --- Bott Operator ---
    W = V @ U @ V.conj().T @ U.conj().T

    # --- Bott index ---
    eigvals_W = la.eigvals(W)
    trace_log = np.sum(np.log(eigvals_W[np.abs(eigvals_W) > 1e-12]))
    bott_index = np.imag(trace_log) / (2 * np.pi)

    return bott_index

# %%
calculate_bott(ham, 10, 3)
# Out:
# 1.526666247102488e-14

# %%
p = 3
q = 4
w2 = 1
w1 = (p/q)*w2
w = w2/q
a = 1
a1 = 1
a2 = 1
g0 = 2
delta = 0.2
u = g0 - delta
v = g0 + delta
theta = 1
L = 20
modes = 8

vari = 0
varf = 2
step = 0.05

# calculate_bott(Hf_finite(modes, u, v, w1, w2, w, theta, a, a1, a2, L), L, modes)
BottIndex_vs_a2 = [calculate_bott(Hf_finite(modes, g0 - i, g0 + i, w1, w2, w, theta, a, a1, a2, L), L, modes) for i in np.arange(vari,varf,step)]

# %%
plt.plot(np.arange(vari,varf,step),BottIndex_vs_a2, 'b-')
plt.plot(np.arange(vari,varf,step),BottIndex_vs_a2, 'ro')
# plt.plot(np.arange(-1,1,0.1),bi_th, 'b-')
# plt.plot(np.arange(-1,1,0.1),bi_th, 'ro')
plt.grid()
plt.xlabel('a2')
plt.ylabel('Bott Index / Chern number')
plt.title('p='+str(p)+' q='+str(q)+' u='+str(u)+' v='+str(v)+' theta='+str(theta)+' modes='+str(modes))
plt.show()
